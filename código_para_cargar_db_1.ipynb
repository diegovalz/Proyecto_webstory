# %% [markdown]
# <a href="https://colab.research.google.com/github/diegovalz/Proyecto_webstory/blob/main/c%C3%B3digo_para_cargar_db_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_inflacion = pd.read_csv('base_datos_limpia.csv')

df_inflacion.head()
# Out:
#         fecha  periodo  tasa_inflacion
# 0  2005-01-31  2005-01             1.9
# 1  2005-02-28  2005-02             2.1
# 2  2005-03-31  2005-03             2.2
# 3  2005-04-30  2005-04             2.1
# 4  2005-05-31  2005-05             2.0
